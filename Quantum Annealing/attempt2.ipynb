# %% [markdown]
# Consider the evolution of a simple Hamiltonian into a problem-specific Hamiltonian where the optimal solution is 'encoded' in the ground state of the problem Hamiltonian $\displaystyle H_{\text{P}}$
#
# $$H\left(s\right) = \left(1 - s\right)H_0 + sH_{\text{P}},\quad\text{where }H_{\text{P}} = \underbrace{A\left[\sum_{j = 0}^{\ell}2^jy_j + \left(c + 1 - 2^{\ell + 1}\right)y_{\ell + 1} - \sum_{i = 1}^nw_ix_i\right]^2}_{H_A} + \underbrace{\left(-B\sum_{i = 1}^np_ix_i\right)}_{H_B}$$
#
# for $\displaystyle s = \frac{t}{T}$ where $T$ is the total computation time and $\displaystyle \ell = \lfloor\log_2c\rfloor$

# %%
from qutip import tensor, basis, sigmaz, sigmaz, qeye, mesolve
import numpy as np

def tensor_sigmaz(i, n):
    ops = [qeye(2) for _ in range(n)]
    ops[i] = sigmaz()
    return tensor(ops)

# Parameters
num_items = 7
profits = np.array([6, 5, 8, 9, 6, 7, 3])
weights = np.array([2, 3, 6, 7, 5, 8, 4])
capacity = 9
A = np.max(profits) + 1
B = 1.0
M = int(np.ceil(np.log2(capacity)))  # Smallest M such that 2^M >= c

total_qubits = num_items + M

# Initial Hamiltonian H_0
H_0 = sum(tensor_sigmaz(i, total_qubits) for i in range(total_qubits))

# Problem Hamiltonian H_P
H_A = A * ((sum(2**j * tensor_sigmaz(num_items + j, total_qubits) for j in range(M)) +
           (capacity + 1 - 2**M) * tensor_sigmaz(num_items + M - 1, total_qubits) -
           sum(weights[i] * tensor_sigmaz(i, total_qubits) for i in range(num_items))) ** 2)

H_B = -B * sum(profits[i] * tensor_sigmaz(i, total_qubits) for i in range(num_items))

H_P = H_A + H_B

# Time-dependent Hamiltonian function
def H(t, args):
    s = t / T
    return (1 - s) * H_0 + s * H_P

T = 1000
times = np.linspace(0, T, 10000)

# Initial state: equal superposition of all states
psi0 = tensor([basis(2, 0) + basis(2, 1) for _ in range(total_qubits)]).unit()

result = mesolve(H, psi0, times, [], [])

psi_final = result.states[-1]

print("Final state probabilities:")
print([abs(psi) ** 2 for psi in psi_final.full().flatten()])
# Out:
# ---------------------------------------------------------------------------
# IntegratorException                       Traceback (most recent call last)
# Cell In[2], line 43
#      40 # Initial state: equal superposition of all states
#      41 psi0 = tensor([basis(2, 0) + basis(2, 1) for _ in range(total_qubits)]).unit()
# ---> 43 result = mesolve(H, psi0, times, [], [])
#      45 psi_final = result.states[-1]
#      47 print("Final state probabilities:")
#
# File c:\Users\raw_asparagus\AppData\Local\Programs\Python\Python312\Lib\site-packages\qutip\solver\mesolve.py:161, in mesolve(H, rho0, tlist, c_ops, _e_ops, _args, _options, e_ops, args, options, **kwargs)
#     158 use_mesolve = len(c_ops) > 0 or (not rho0.isket) or H.issuper
#     160 if not use_mesolve:
# --> 161     return sesolve(H, rho0, tlist, e_ops=e_ops, args=args,
#     162                    options=options)
#     164 solver = MESolver(H, c_ops, options=options)
#     166 return solver.run(rho0, tlist, e_ops=e_ops)
#
# File c:\Users\raw_asparagus\AppData\Local\Programs\Python\Python312\Lib\site-packages\qutip\solver\sesolve.py:127, in sesolve(H, psi0, tlist, _e_ops, _args, _options, e_ops, args, options, **kwargs)
#     125 H = QobjEvo(H, args=args, tlist=tlist)
#     126 solver = SESolver(H, options=options)
# --> 127 return solver.run(psi0, tlist, e_ops=e_ops)
#
# File c:\Users\raw_asparagus\AppData\Local\Programs\Python\Python312\Lib\site-packages\qutip\solver\solver_base.py:197, in Solver.run(self, state0, tlist, e_ops, args)
#     192 stats['preparation time'] += time() - _time_start
#     194 progress_bar = progress_bars[self.options['progress_bar']](
#     195     len(tlist)-1, **self.options['progress_kwargs']
#     196 )
# --> 197 for t, state in self._integrator.run(tlist):
#     198     progress_bar.update()
#     199     results.add(t, self._restore_state(state, copy=False))
#
# File c:\Users\raw_asparagus\AppData\Local\Programs\Python\Python312\Lib\site-packages\qutip\solver\integrator\integrator.py:201, in Integrator.run(self, tlist)
#     187 """
#     188 Integrate the system yielding the state for each times in tlist.
#     189
#    (...)
#     198     The state of the solver at each ``t`` of tlist.
#     199 """
#     200 for t in tlist[1:]:
# --> 201     yield self.integrate(t, False)
#
# File c:\Users\raw_asparagus\AppData\Local\Programs\Python\Python312\Lib\site-packages\qutip\solver\integrator\scipy_integrator.py:111, in IntegratorScipyAdams.integrate(self, t, copy)
#     109 if t != self._ode_solver.t:
#     110     self._ode_solver.integrate(t)
# --> 111 return self.get_state(copy)
#
# File c:\Users\raw_asparagus\AppData\Local\Programs\Python\Python312\Lib\site-packages\qutip\solver\integrator\scipy_integrator.py:86, in IntegratorScipyAdams.get_state(self, copy)
#      84 if not self._is_set:
#      85     raise IntegratorException("The state is not initialted")
# ---> 86 self._check_failed_integration()
#      87 t = self._ode_solver.t
#      88 if self._mat_state:
#
# File c:\Users\raw_asparagus\AppData\Local\Programs\Python\Python312\Lib\site-packages\qutip\solver\integrator\scipy_integrator.py:157, in IntegratorScipyAdams._check_failed_integration(self)
#     145     return
#     146 messages = {
#     147     -1: 'Excess work done on this call. Try to increasing '
#     148         'the nsteps parameter in the Options class',
#    (...)
#     155         ' component i vanished, and ATOL or ATOL(i) = 0.)'
#     156 }
# --> 157 raise IntegratorException(
#     158     messages[self._ode_solver._integrator.istate]
#     159 )
#
# IntegratorException: Excess work done on this call. Try to increasing the nsteps parameter in the Options class

# %%
H_P.full()
# Out:
# array([[ 6716.+0.j,     0.+0.j,     0.+0.j, ...,     0.+0.j,     0.+0.j,
#             0.+0.j],
#        [    0.+0.j,  8956.+0.j,     0.+0.j, ...,     0.+0.j,     0.+0.j,
#             0.+0.j],
#        [    0.+0.j,     0.+0.j, 11516.+0.j, ...,     0.+0.j,     0.+0.j,
#             0.+0.j],
#        ...,
#        [    0.+0.j,     0.+0.j,     0.+0.j, ..., 11604.+0.j,     0.+0.j,
#             0.+0.j],
#        [    0.+0.j,     0.+0.j,     0.+0.j, ...,     0.+0.j,  9044.+0.j,
#             0.+0.j],
#        [    0.+0.j,     0.+0.j,     0.+0.j, ...,     0.+0.j,     0.+0.j,
#          6804.+0.j]], shape=(2048, 2048))

# %%
np.set_printoptions(suppress=True)

# %%
np.diag(H_P.full())
# Out:
# array([ 6716.+0.j,  8956.+0.j, 11516.+0.j, ..., 11604.+0.j,  9044.+0.j,
#         6804.+0.j], shape=(2048,))

# %%
H_A = A * ((sum(2**j * tensor_sigmaz(num_items + j, total_qubits) for j in range(M)) +
           (capacity + 1 - 2**M) * tensor_sigmaz(num_items + M - 1, total_qubits) -
           sum(weights[i] * tensor_sigmaz(i, total_qubits) for i in range(num_items))) ** 2)

H_B = -B * sum(profits[i] * tensor_sigmaz(i, total_qubits) for i in range(num_items))

H_P = H_A + H_B

print(H_P.full())
# Out:
# [[ 6716.+0.j     0.+0.j     0.+0.j ...     0.+0.j     0.+0.j     0.+0.j]
#  [    0.+0.j  8956.+0.j     0.+0.j ...     0.+0.j     0.+0.j     0.+0.j]
#  [    0.+0.j     0.+0.j 11516.+0.j ...     0.+0.j     0.+0.j     0.+0.j]
#  ...
#  [    0.+0.j     0.+0.j     0.+0.j ... 11604.+0.j     0.+0.j     0.+0.j]
#  [    0.+0.j     0.+0.j     0.+0.j ...     0.+0.j  9044.+0.j     0.+0.j]
#  [    0.+0.j     0.+0.j     0.+0.j ...     0.+0.j     0.+0.j  6804.+0.j]]

# %%
print(H_A.full())
# Out:
# [[ 6760.+0.j     0.+0.j     0.+0.j ...     0.+0.j     0.+0.j     0.+0.j]
#  [    0.+0.j  9000.+0.j     0.+0.j ...     0.+0.j     0.+0.j     0.+0.j]
#  [    0.+0.j     0.+0.j 11560.+0.j ...     0.+0.j     0.+0.j     0.+0.j]
#  ...
#  [    0.+0.j     0.+0.j     0.+0.j ... 11560.+0.j     0.+0.j     0.+0.j]
#  [    0.+0.j     0.+0.j     0.+0.j ...     0.+0.j  9000.+0.j     0.+0.j]
#  [    0.+0.j     0.+0.j     0.+0.j ...     0.+0.j     0.+0.j  6760.+0.j]]

# %%
print(H_B.full())
# Out:
# [[-44.+0.j   0.+0.j   0.+0.j ...   0.+0.j   0.+0.j   0.+0.j]
#  [  0.+0.j -44.+0.j   0.+0.j ...   0.+0.j   0.+0.j   0.+0.j]
#  [  0.+0.j   0.+0.j -44.+0.j ...   0.+0.j   0.+0.j   0.+0.j]
#  ...
#  [  0.+0.j   0.+0.j   0.+0.j ...  44.-0.j   0.+0.j   0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j ...   0.+0.j  44.-0.j   0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j ...   0.+0.j   0.+0.j  44.-0.j]]

# %%
import matplotlib.pyplot as plt

all_probabilities = [np.abs(state.full())**2 for state in result.states]

plt.figure(figsize=(10, 6), dpi=300)
for idx in range(2**(num_items + 4)):
    plt.plot(times, [prob[idx] for prob in all_probabilities], label=f'State |{format(idx, "0" + str(num_items + 4) + "b")}>')
plt.xlabel('Time')
plt.ylabel('Probability')
plt.title('Probabilities of States Over Time')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

all_probabilities = [np.abs(state.full())**2 for state in result.states]

probs = [np.sum(states) for states in all_probabilities]

plt.figure(figsize=(10, 6), dpi=300)
plt.plot(times, probs)
plt.xlabel('Time')
plt.ylabel('Probability')
plt.ylim(0,1.2)
plt.title('Probabilities of States Over Time')
# plt.legend()
plt.show()

# %%
final_probabilities = np.abs(psi_final.full().flatten())**2

max_prob_index = np.argmax(final_probabilities)

most_probable_state = format(max_prob_index, '0' + str(total_qubits) + 'b')

print(f"Most probable state: {most_probable_state}")
print(f"Probability of this state: {final_probabilities[max_prob_index]}")

item_inclusion = [int(bit) for bit in most_probable_state[:num_items]]
print("Item inclusion (1 = included, 0 = not included):", item_inclusion)

total_weight = sum(weights[i] * item_inclusion[i] for i in range(num_items))
total_profit = sum(profits[i] * item_inclusion[i] for i in range(num_items))

print(f"Total weight of most probable configuration: {total_weight}")
print(f"Total profit of most probable configuration: {total_profit}")

plt.figure(figsize=(12, 8))
for idx in range(2**total_qubits):
    state_prob = [prob[idx] for prob in all_probabilities]
    plt.plot(times, state_prob, label=f'State |{format(idx, "0" + str(total_qubits) + "b")}>')
plt.xlabel('Time')
plt.ylabel('Probability')
plt.title('Probabilities of States Over Time')
plt.show()
# Out:
# Most probable state: 11111110000
# Probability of this state: 0.01984330146832208
# Item inclusion (1 = included, 0 = not included): [1, 1, 1, 1, 1, 1, 1]
# Total weight of most probable configuration: 35
# Total profit of most probable configuration: 44

# %%
X = A * ((sum(2**j * tensor_sigmaz(num_items + j, total_qubits) for j in range(M))) ** 1)

print(X.full())
# Out:
# [[ 150.+0.j    0.+0.j    0.+0.j ...    0.+0.j    0.+0.j    0.+0.j]
#  [   0.+0.j  -10.+0.j    0.+0.j ...    0.+0.j    0.+0.j    0.+0.j]
#  [   0.+0.j    0.+0.j   70.+0.j ...    0.+0.j    0.+0.j    0.+0.j]
#  ...
#  [   0.+0.j    0.+0.j    0.+0.j ...  -70.+0.j    0.+0.j    0.+0.j]
#  [   0.+0.j    0.+0.j    0.+0.j ...    0.+0.j   10.+0.j    0.+0.j]
#  [   0.+0.j    0.+0.j    0.+0.j ...    0.+0.j    0.+0.j -150.+0.j]]

# %%
Y = A * (((capacity + 1 - 2**M) * tensor_sigmaz(num_items + M - 1, total_qubits)) ** 1)

print(Y.full())
# Out:
# [[-60.+0.j   0.+0.j   0.+0.j ...   0.+0.j   0.+0.j   0.+0.j]
#  [  0.+0.j  60.+0.j   0.+0.j ...   0.+0.j   0.+0.j   0.+0.j]
#  [  0.+0.j   0.+0.j -60.+0.j ...   0.+0.j   0.+0.j   0.+0.j]
#  ...
#  [  0.+0.j   0.+0.j   0.+0.j ...  60.+0.j   0.+0.j   0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j ...   0.+0.j -60.+0.j   0.+0.j]
#  [  0.+0.j   0.+0.j   0.+0.j ...   0.+0.j   0.+0.j  60.+0.j]]

# %%
Z = A * ((sum(weights[i] * tensor_sigmaz(i, total_qubits) for i in range(num_items))) ** 1)

print(Z.full())
# Out:
# [[ 350.+0.j    0.+0.j    0.+0.j ...    0.+0.j    0.+0.j    0.+0.j]
#  [   0.+0.j  350.+0.j    0.+0.j ...    0.+0.j    0.+0.j    0.+0.j]
#  [   0.+0.j    0.+0.j  350.+0.j ...    0.+0.j    0.+0.j    0.+0.j]
#  ...
#  [   0.+0.j    0.+0.j    0.+0.j ... -350.+0.j    0.+0.j    0.+0.j]
#  [   0.+0.j    0.+0.j    0.+0.j ...    0.+0.j -350.+0.j    0.+0.j]
#  [   0.+0.j    0.+0.j    0.+0.j ...    0.+0.j    0.+0.j -350.+0.j]]
